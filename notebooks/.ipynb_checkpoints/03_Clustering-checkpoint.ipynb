# %% [markdown]
# # Lab | Unsupervised learning intro
#
# ## Instructions
# It's the moment to perform clustering on the songs you collected. Remember that the ultimate goal of this little project is to improve the recommendations of artists. Clustering the songs will allow the recommendation system to limit the scope of the recommendations to only songs that belong to the same cluster - songs with similar audio features.
#
# The experiments you did with the Spotify API and the Billboard web scraping will allow you to create a pipeline such that when the user enters a song, you:
#
# 1. Check whether or not the song is in the Billboard Hot 200.
# 2. Collect the audio features from the Spotify API.
#
# After that, you want to send the Spotify audio features of the submitted song to the clustering model, which should return a cluster number.
#
# We want to have as many songs as possible to create the clustering model, so we will add the songs you collected to a bigger dataset available on Kaggle containing 160 thousand songs.

# %%
import pandas as pd
import time
import numpy as np
from sklearn import cluster
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline
import joblib

# %% [markdown]
# ## Preparing and scaling the dataframe

# %%
### I am using the dataframes exported before

# %%
top_1971_2021 = pd.read_csv(r'C:\Users\luana\github\spotify-song-recommender\csv_files\top_1971_2021.csv')
top_1971_2021
# Out:
#                                 song               artist  popularity  \
# 0          Levitating (feat. DaBaby)    Dua Lipa & DaBaby          85
# 1                    drivers license       Olivia Rodrigo          88
# 2                    Save Your Tears           The Weeknd          90
# 3     MONTERO (Call Me By Your Name)            Lil Nas X          83
# 4                    Blinding Lights           The Weeknd          91
# ...                              ...                  ...         ...
# 4904    He's Gonna Step on You Again          John Kongos          28
# 4905                      Wild World  Yusuf / Cat Stevens          77
# 4906                  Love Her Madly            The Doors          66
# 4907                   Amazing Grace         Judy Collins          45
# 4908   Peace Train - Remastered 2021  Yusuf / Cat Stevens          66
#
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# ...

# %%
genres = pd.read_csv(r'C:\Users\luana\IH-Labs\lab-web-scraping-multiple-pages\songs_genre.csv')
genres
# Out:
#                                                 song  \
# 0                                          As It Was
# 1                                            Perfect
# 2     STAR WALKIN' (League of Legends Worlds Anthem)
# 3                                   Treat You Better
# 4                                         Dark Horse
# ...                                              ...
# 4312                                         Starter
# 4313                                       Chromatic
# 4314                I'm The Joker (feat. DJ Supreme)
# 4315                                     Slow Motion
# 4316                                     Find My Way
#
#                              artist  popularity  danceability  energy  key  \
# 0                      Harry Styles          93         0.520   0.731    6
# 1                        Ed Sheeran          88         0.599   0.448    8
# 2                         Lil Nas X          90         0.637   0.715    2
# ...

# %%
tracks = pd.read_csv(r'C:\Users\luana\IH-Labs\lab-web-scraping-multiple-pages\tracks.csv')
tracks
# Out:
#                   artist_name                track_id  \
# 0                          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1                          YG  1tHDG53xJNGsItRA3vfVgs
# 2                       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3                  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4                  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
# ...                       ...                     ...
# 130658            Calum Scott  0cvfSKcm9VeduwyYPrxtLx
# 130659           Saint Claire  43MP9F7UzvfilSrw2SqZGJ
# 130660              Mike Stud  4TWlUuFk81NGUNKwndyS5Q
# 130661               D Savage  5iGBXzOoRo4sBTy8wdzMyK
# 130662  Banda Los Sebastianes  7LNtyuekYHiZ99UxkrfCQR
#
#                                             track_name  acousticness  \
# 0       Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820
# 1                         BAND DRUM (feat. A$AP Rocky)      0.024400
# 2                                        Radio Silence      0.025000
# ...

# %%
tracks = tracks.drop(columns=['popularity'], axis=1)
tracks = tracks.rename(columns= {'track_name': 'song', 'artist_name':'artist', 'track_id': 'id'})
tracks
# Out:
#                        artist                      id  \
# 0                          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1                          YG  1tHDG53xJNGsItRA3vfVgs
# 2                       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3                  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4                  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
# ...                       ...                     ...
# 130658            Calum Scott  0cvfSKcm9VeduwyYPrxtLx
# 130659           Saint Claire  43MP9F7UzvfilSrw2SqZGJ
# 130660              Mike Stud  4TWlUuFk81NGUNKwndyS5Q
# 130661               D Savage  5iGBXzOoRo4sBTy8wdzMyK
# 130662  Banda Los Sebastianes  7LNtyuekYHiZ99UxkrfCQR
#
#                                                   song  acousticness  \
# 0       Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820
# 1                         BAND DRUM (feat. A$AP Rocky)      0.024400
# 2                                        Radio Silence      0.025000
# ...

# %%
tracks =  tracks[['song', 'artist', 'danceability', 'energy', 'key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'id', 'duration_ms', 'time_signature']]
tracks
# Out:
#                                                   song                 artist  \
# 0       Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj                     YG
# 1                         BAND DRUM (feat. A$AP Rocky)                     YG
# 2                                        Radio Silence                  R3HAB
# 3                                              Lactose             Chris Cooq
# 4                                  Same - Original mix             Chris Cooq
# ...                                                ...                    ...
# 130658                                  Come Back Home            Calum Scott
# 130659                                  Enough for You           Saint Claire
# 130660                                           Do It              Mike Stud
# 130661                                        No Smoke               D Savage
# 130662                                         En Vida  Banda Los Sebastianes
#
# ...

# %%
songs = pd.concat([top_1971_2021, genres, tracks], axis=0)
songs
# Out:
#                                   song                 artist  popularity  \
# 0            Levitating (feat. DaBaby)      Dua Lipa & DaBaby        85.0
# 1                      drivers license         Olivia Rodrigo        88.0
# 2                      Save Your Tears             The Weeknd        90.0
# 3       MONTERO (Call Me By Your Name)              Lil Nas X        83.0
# 4                      Blinding Lights             The Weeknd        91.0
# ...                                ...                    ...         ...
# 130658                  Come Back Home            Calum Scott         NaN
# 130659                  Enough for You           Saint Claire         NaN
# 130660                           Do It              Mike Stud         NaN
# 130661                        No Smoke               D Savage         NaN
# 130662                         En Vida  Banda Los Sebastianes         NaN
#
#         danceability  energy   key  loudness  mode  speechiness  acousticness  \
# ...

# %%
songs = songs.drop(columns=['popularity','type', 'uri', 'track_href','analysis_url'], axis=1).dropna().drop_duplicates(['id']).reset_index(drop=True)
songs
# Out:
#                                   song                 artist  danceability  \
# 0            Levitating (feat. DaBaby)      Dua Lipa & DaBaby         0.702
# 1                      drivers license         Olivia Rodrigo         0.561
# 2                      Save Your Tears             The Weeknd         0.680
# 3       MONTERO (Call Me By Your Name)              Lil Nas X         0.593
# 4                      Blinding Lights             The Weeknd         0.514
# ...                                ...                    ...           ...
# 138601                  Come Back Home            Calum Scott         0.601
# 138602                  Enough for You           Saint Claire         0.387
# 138603                           Do It              Mike Stud         0.717
# 138604                        No Smoke               D Savage         0.772
# 138605                         En Vida  Banda Los Sebastianes         0.715
#
# ...

# %%
songs.to_csv(r'C:\Users\luana\IH-Labs\lab-web-scraping-multiple-pages\songs.csv', index = False, header=True)

# %%
X = songs.select_dtypes(np.number)
y = songs['song']
X
# Out:
#         danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0              0.702   0.825   6.0    -3.787   0.0       0.0601       0.00883
# 1              0.561   0.431  10.0    -8.810   1.0       0.0578       0.76800
# 2              0.680   0.826   0.0    -5.487   1.0       0.0309       0.02120
# 3              0.593   0.503   8.0    -6.725   0.0       0.2200       0.29300
# 4              0.514   0.730   1.0    -5.934   1.0       0.0598       0.00146
# ...              ...     ...   ...       ...   ...          ...           ...
# 138601         0.601   0.801  11.0    -5.174   1.0       0.0323       0.00678
# 138602         0.387   0.249   9.0   -13.233   1.0       0.0437       0.91800
# 138603         0.717   0.532   8.0    -8.351   0.0       0.2060       0.33000
# 138604         0.772   0.510   4.0    -9.670   0.0       0.1200       0.00790
# 138605         0.715   0.734   3.0    -3.244   1.0       0.0367       0.54900
#
# ...

# %%
scaler = StandardScaler().fit(X)
joblib.dump(scaler, 'scaler.save') # saving scaler to use in the recommender
X_prep = pd.DataFrame(scaler.transform(X), columns = X.columns)
X_prep
# Out:
#         danceability    energy       key  loudness      mode  speechiness  \
# 0           0.634731  0.970309  0.213117  0.941077 -1.252280    -0.403835
# 1          -0.108902 -0.539648  1.323930  0.175495  0.798544    -0.422660
# 2           0.518704  0.974142 -1.453102  0.681971  0.798544    -0.642834
# 3           0.059866 -0.263716  0.768523  0.493281 -1.252280     0.904927
# 4          -0.356780  0.606233 -1.175399  0.613841  0.798544    -0.406291
# ...              ...       ...       ...       ...       ...          ...
# 138601      0.102058  0.878332  1.601633  0.729677  0.798544    -0.631375
# 138602     -1.026577 -1.237140  1.046227 -0.498639  0.798544    -0.538067
# 138603      0.713841 -0.152577  0.768523  0.245453 -1.252280     0.790338
# 138604      1.003911 -0.236890 -0.342289  0.044417 -1.252280     0.086439
# 138605      0.703293  0.621563 -0.619993  1.023839  0.798544    -0.595361
#
#         acousticness  instrumentalness  liveness   valence     tempo  \
# ...

# %% [markdown]
# ## Choosing k and clustering

# %% [markdown]
# ### Elbow method

# %%
# %%time
K = range(2, 30)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# CPU times: total: 58min 28s
# Wall time: 9min 57s
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
# %%time

kmeans = KMeans(n_clusters=40,random_state=1234)
model = kmeans.fit(X_prep)
joblib.dump(model, 'model.save') # saving model to use in the recommender
clusters = model.predict(X_prep)
display(pd.Series(clusters).value_counts().sort_index())
# Out:
# 0     3002
# 1     6750
# 2     6433
# 3     4155
# 4     3549
# 5     6573
# 6     1074
# 7     1742
# 8     6922
# 9     4560
# 10     345
# 11    2617
# 12      65
# 13    2505
# 14    3060
# 15    4071
# 16    3363
# 17    6113
# 18    3516
# 19    2725
# 20    2993
# 21    3485
# 22    4515
# 23    2314
# 24    3764
# 25    1223
# 26    3101
# 27    3893
# 28    2168
# 29    1000
# 30    1192
# 31    2046
# 32    6230
# 33    2118
# 34    3332
# 35    4018
# 36    4507
# 37    2781
# 38    3953
# 39    6833
# dtype: int64
# CPU times: total: 1min 13s
# Wall time: 12.1 s

# %%
songs_clustered = songs
songs_clustered['cluster']= clusters
songs_clustered
# Out:
#                                   song                 artist  danceability  \
# 0            Levitating (feat. DaBaby)      Dua Lipa & DaBaby         0.702
# 1                      drivers license         Olivia Rodrigo         0.561
# 2                      Save Your Tears             The Weeknd         0.680
# 3       MONTERO (Call Me By Your Name)              Lil Nas X         0.593
# 4                      Blinding Lights             The Weeknd         0.514
# ...                                ...                    ...           ...
# 138601                  Come Back Home            Calum Scott         0.601
# 138602                  Enough for You           Saint Claire         0.387
# 138603                           Do It              Mike Stud         0.717
# 138604                        No Smoke               D Savage         0.772
# 138605                         En Vida  Banda Los Sebastianes         0.715
#
# ...

# %%
songs_clustered.to_csv(r'C:\Users\luana\IH-Labs\lab-web-scraping-multiple-pages\songs_clustered.csv', index = False, header=True)
