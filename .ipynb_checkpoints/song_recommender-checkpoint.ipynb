# %% [markdown]
# ## Lab | Web Scraping Single Page
#
# ### Instructions - Scraping popular songs
# Your product will take a song as an input from the user and will output another song (the recommendation). In most cases, the recommended song will have to be similar to the inputted song, but the CTO thinks that if the song is on the top charts at the moment, the user will enjoy more a recommendation of a song that's also popular at the moment.
#
# You have find data on the internet about currently popular songs. Billboard maintains a weekly Top 100 of "hot" songs here: https://www.billboard.com/charts/hot-100.
#
# It's a good place to start! Scrape the current top 100 songs and their respective artists, and put the information into a pandas dataframe.

# %% [markdown]
# ### Hot Songs (Top 100 this week)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from time import sleep
import random
from time import sleep
from random import randint
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import datetime
import time

# %%
url = 'https://www.popvortex.com/music/charts/top-100-songs.php'

# %%
response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
# soup

# %%
# extracting lists
song = []
artist = []

num_iter = len(soup.select("p > cite"))

song_list = soup.select("p > cite")
artist_list = soup.select("p > em ")


# iterate through the result set and retrive all the data
for i in range(num_iter):
    song.append(song_list[i].get_text())
    artist.append(artist_list[i].get_text())

print(song)
print(artist)
# Out:
# ['Unholy', "I'm Good (Blue)", 'Thank God', 'wait in the truck', 'Son Of A Sinner', 'You Proof', 'A Thousand Years', 'Everywhere', 'Unstoppable', "I Ain't Worried", 'Left and Right', 'She Had Me At Heads Carolina', 'Fall In Love', 'Wasted On You', 'CUFF IT', 'Under the Influence', 'The Kind of Love We Make', 'Eagle (feat. KB)', 'Make It With You', 'Life Is a Highway', 'Super Freaky Girl', 'Lose Yourself', 'Shivers', 'As It Was', 'Shallow', 'Celestial', 'About Damn Time', 'the mockingbird & THE CROW', 'Sunroof', 'Fingers Crossed', 'KICK BACK', 'Love Me Like You Do', 'Hold Me Closer', 'TRUCK BED', 'Rock and a Hard Place', 'I Like You (A Happier Song) [feat. Doja Cat]', 'Victoria’s Secret', 'Soul', 'Next Thing You Know', 'Bust Your Windows', 'here lies country music', 'Earned It', "You'll Be In My Heart", 'Somewhere Over the Rainbow', "Something in the Orange (Z&E's Version)", 'What My World Spins Around', '2 Be Loved (Am I Ready)', 'Tennessee Orange', 'Bad Habit', 'Vegas (From the Original Motion Picture Soundtrack ELVIS)', 'Way of the Triune God (Hallelujah Version)', 'This Is Halloween', 'Neon You', '1,2,3 Eoi!', 'Numb', "STAR WALKIN' (League of Legends Worlds Anthem)", 'Something in the Orange', 'It Will Rain', 'Never Leave', 'Forget Me', 'How Do I Say Goodbye', 'Always Remember Us This Way', 'Cold Heart (PNAU Remix)', 'Starved', "'Til You Can't", 'Joy of My Life', 'Poland', 'Forever', 'Monster Mash', 'Running Up That Hill (A Deal with God)', 'Don’t Come Lookin’', 'Everything I Own', 'Tennessee Whiskey', 'Bones', "Baby I'm-A Want You", 'Perfectly Loved (feat. TobyMac)', "Gangsta's Paradise (feat. L.V.)", "World's Smallest Violin", 'down home', 'Half Of Me (feat. Riley Green)', 'No Body', 'Late Night Talking', 'Tití Me Preguntó', 'CUFF IT', 'Build a Boat', 'High Heels', '5 Foot 9', 'God Is In This Story', 'She Likes It (feat. Jake Scott)', 'No Se Va (En Vivo)', "I'm Good (Blue)", 'Enough', 'If', 'Love Me Like I Am', 'Tomorrow 2', 'Hold My Hand', 'One Way or Another (Hocus Pocus 2 Version)', "How Far I'll Go", 'Betty (Get Money)', 'golden hour']
# ['Sam Smith & Kim Petras', 'David Guetta & Bebe Rexha', 'Kane Brown & Katelyn Brown', 'HARDY & Lainey Wilson', 'Jelly Roll', 'Morgan Wallen', 'Christina Perri', 'Fleetwood Mac', 'Sia', 'OneRepublic', 'Charlie Puth & Jung Kook', 'Cole Swindell', 'Bailey Zimmerman', 'Morgan Wallen', 'Beyoncé', 'Chris Brown', 'Luke Combs', 'Transformation Worship', 'Bread', 'Rascal Flatts', 'Nicki Minaj', 'Eminem', 'Ed Sheeran', 'Harry Styles', 'Lady Gaga & Bradley Cooper', 'Ed Sheeran', 'Lizzo', 'HARDY', 'Nicky Youre & Dazy', 'Lauren Spencer Smith', 'Kenshi Yonezu', 'Ellie Goulding', 'Elton John & Britney Spears', 'HARDY', 'Bailey Zimmerman', 'Post Malone', 'Jax', 'Lee Brice', 'Jordan Davis', 'Jazmine Sullivan', 'HARDY', 'The Weeknd', 'Phil Collins', "Israel Kamakawiwo'ole", 'Zach Bryan', 'Jordan Davis', 'Lizzo', 'Megan Moroney', 'Steve Lacy', 'Doja Cat', 'Tyler Childers', 'The Citizens of Halloween', 'Don Louis', 'MAMAMOO', 'Marshmello & Khalid', 'Lil Nas X', 'Zach Bryan', 'Bruno Mars', 'Bailey Zimmerman', 'Lewis Capaldi', 'Dean Lewis', 'Lady Gaga', 'Elton John & Dua Lipa', 'Zach Bryan', 'Cody Johnson', 'Chris Stapleton', 'Lil Yachty', 'Drake, Kanye West, Lil Wayne & Eminem', 'Bobby "Boris" Pickett & The Crypt-Kickers', 'Kate Bush', 'Jackson Dean', 'Bread', 'Chris Stapleton', 'Imagine Dragons', 'Bread', 'Rachael Lampa', 'Coolio', 'AJR', 'Jimmie Allen', 'Thomas Rhett', 'Blake Shelton', 'Harry Styles', 'Bad Bunny', 'Beyoncé', 'Colton Dixon', 'Flo Rida & Walker Hayes', 'Tyler Hubbard', 'Katy Nichole & Big Daddy Weave', 'Russell Dickerson & Jake Scott', 'Grupo Frontera', 'David Guetta & Bebe Rexha', 'charlieonnafriday', 'Bread', 'for KING & COUNTRY & Jordin Sparks', 'GloRilla & Cardi B', 'Lady Gaga', 'Bette Midler, Sarah Jessica Parker & Kathy Najimy', "Auli'i Cravalho", 'Yung Gravy', 'JVKE']

# %%
#creating dataframe

hot_songs = pd.DataFrame({"song":song,
                       "artist":artist
                      })
hot_songs
# Out:
#                                           song  \
# 0                                       Unholy
# 1                              I'm Good (Blue)
# 2                                    Thank God
# 3                            wait in the truck
# 4                              Son Of A Sinner
# ..                                         ...
# 95                                Hold My Hand
# 96  One Way or Another (Hocus Pocus 2 Version)
# 97                             How Far I'll Go
# 98                           Betty (Get Money)
# 99                                 golden hour
#
#                                                artist
# 0                              Sam Smith & Kim Petras
# 1                           David Guetta & Bebe Rexha
# 2                          Kane Brown & Katelyn Brown
# 3                               HARDY & Lainey Wilson
# 4                                          Jelly Roll
# ..                                                ...
# 95                                          Lady Gaga
# 96  Bette Midler, Sarah Jessica Parker & Kathy Najimy
# 97                                    Auli'i Cravalho
# 98                                         Yung Gravy
# 99                                               JVKE
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Lab | Web Scraping Multiple Pages
#
# ### Instructions - Scraping popular songs
#
# Prioritize the MVP
# In the previous lab, you had to scrape data about "hot songs". It's critical to be on track with that part, as it was part of the request from the CTO.
#
# If you couldn't finish the first lab, use this time to go back there.
#
# Expand the project
# If you're done, you can try to expand the project on your own. Here are a few suggestions:
#
# Find other lists of hot songs on the internet and scrape them too: having a bigger pool of songs will be awesome!
# Apply the same logic to other "groups" of songs: the best songs from a decade or from a country / culture / language / genre.
# Wikipedia maintains a large collection of lists of songs: https://en.wikipedia.org/wiki/Lists_of_songs

# %% [markdown]
# ### Top hits by year

# %%
# I wanna do the same thing for several years, so I will create a function

def url_text(year):
    url = str("https://playback.fm/charts/top-100-songs/"+str(year))
    return url

url2 = url_text(2021)

# %%
response2 = requests.get(url2)
response2.status_code # 200 status code means OK!

soup2 = BeautifulSoup(response2.content, "html.parser")
# soup2

# %%
print(soup2.select('.song')[0].get_text())
print(soup2.select('.song')[1].get_text())
print(soup2.select('.song')[198].get_text())
print(soup2.select('.song')[199].get_text())
# each song is coming up twice, so I will have to pay attention to the indexes
# Out:
# Levitating
#
#
# Levitating
#
#
# Thot Shit
#
#
# Thot Shit

# %%
soup2.select('.artist')[0].get_text()
soup2.select('.artist')[99].get_text() #this will need cleaning
# Out:
# '\nMegan Thee Stallion\n'

# %%
#Now that I know how to find the data and what the outcome is, I can create a function

def pop_songs_by_year(year):
    try:    
        url = str("https://playback.fm/charts/top-100-songs/"+str(year))
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")

        songs_list = soup.select('.song')
        artists_list = soup.select('.artist')

        song = []
        artist = []

        for i in range (len(songs_list)):
            if i%2 !=0:
                song.append(songs_list[i].get_text())
            else:
                pass

        for i in range (len(artists_list)):
            artist.append(artists_list[i].get_text())
            artist[i]=artist[i].replace('\n','')

        top_songs = pd.DataFrame({"song":song,
                                  "artist":artist})

        top_songs['year'] = str(year)

        wait_time = randint(1,4)
        sleep(wait_time)
    
    except Exception:
        pass
    
    return top_songs

# %% [markdown]
# ### !!! Careful with next cell! Long running time!!!

# %%
# # Scraping the 100 most popular songs for the last 50 years.

# songs_df = pop_songs_by_year(2021)

# list_of_years = []
# for year in range (50):
#     list_of_years.append(2020-year)

# for index in range(len(list_of_years)):
#     songs_df = pd.concat([songs_df, pop_songs_by_year(list_of_years[index])])

# %%
songs_df
# Out:
#                               song                      artist  year
# 0                       Levitating           Dua Lipa & DaBaby  2021
# 1                  Drivers License              Olivia Rodrigo  2021
# 2                  Save Your Tears  The Weeknd & Ariana Grande  2021
# 3   Montero (Call Me by Your Name)                   Lil Nas X  2021
# 4                  Blinding Lights                  The Weeknd  2021
# ..                             ...                         ...   ...
# 95    He's Gonna Step On You Again                 John Kongos  1971
# 96                      Wild World                 Cat Stevens  1971
# 97                  Love Her Madly                   The Doors  1971
# 98                   Amazing Grace                Judy Collins  1971
# 99                     Peace Train                 Cat Stevens  1971
#
# [5097 rows x 3 columns]

# %%
#exporting csv so that I dont have to run it again every time I restart the notebook
songs_df.to_csv(r'C:\Users\luana\IH-Labs\lab-web-scraping-multiple-pages\songs_df.csv', index = False, header=True)

# %% [markdown]
# ### Merging hot songs this week with top songs by year

# %%
hot_songs["year"]=2022
hot_songs
# Out:
#                                           song  \
# 0                                       Unholy
# 1                              I'm Good (Blue)
# 2                                    Thank God
# 3                            wait in the truck
# 4                              Son Of A Sinner
# ..                                         ...
# 95                                Hold My Hand
# 96  One Way or Another (Hocus Pocus 2 Version)
# 97                             How Far I'll Go
# 98                           Betty (Get Money)
# 99                                 golden hour
#
#                                                artist  year
# 0                              Sam Smith & Kim Petras  2022
# 1                           David Guetta & Bebe Rexha  2022
# 2                          Kane Brown & Katelyn Brown  2022
# 3                               HARDY & Lainey Wilson  2022
# 4                                          Jelly Roll  2022
# ..                                                ...   ...
# 95                                          Lady Gaga  2022
# 96  Bette Midler, Sarah Jessica Parker & Kathy Najimy  2022
# 97                                    Auli'i Cravalho  2022
# 98                                         Yung Gravy  2022
# 99                                               JVKE  2022
#
# [100 rows x 3 columns]

# %%
#Not gonna run everything again. I will use the csv
songs_df= pd.read_csv(r'C:\Users\luana\IH-Labs\lab-web-scraping-multiple-pages\songs_df.csv')

hot_top_songs = pd.concat([hot_songs, songs_df], axis=0).reset_index(drop=True)

hot_top_songs['song'] = hot_top_songs['song'].str.lower()
hot_top_songs['artist'] = hot_top_songs['artist'].str.lower()
hot_top_songs

#I think 5000 songs are enough for now :)
# Out:
#                               song                      artist  year
# 0                           unholy      sam smith & kim petras  2022
# 1                  i'm good (blue)   david guetta & bebe rexha  2022
# 2                        thank god  kane brown & katelyn brown  2022
# 3                wait in the truck       hardy & lainey wilson  2022
# 4                  son of a sinner                  jelly roll  2022
# ...                            ...                         ...   ...
# 5192  he's gonna step on you again                 john kongos  1971
# 5193                    wild world                 cat stevens  1971
# 5194                love her madly                   the doors  1971
# 5195                 amazing grace                judy collins  1971
# 5196                   peace train                 cat stevens  1971
#
# [5197 rows x 3 columns]

# %% [markdown]
# ### Starting the Song Recommender

# %%
def song_recommender():
    user_song = str(input('Please enter the name of a song you like\n')).lower()
    if user_song in hot_top_songs['song'].tolist():
        i = random.randint(0,len(hot_top_songs))
        print('You may also like',hot_top_songs['song'][i].title(), "by",hot_top_songs['artist'][i].title())
    else:
        print('There is no song recommendation for you now. Please try again later')

# %%
song_recommender()
# Out:
# Please enter the name of a song you like
# Unholy
# You may also like Always by Atlantic Starr

# %%
song_recommender()
# Out:
# Please enter the name of a song you like
# Hello
# You may also like Bad And Boujee by Migos Featuring Lil Uzi Vert

# %%
song_recommender()
# Out:
# Please enter the name of a song you like
# song not in the list
# There is no song recommendation for you now. Please try again later

# %% [markdown]
# # Lab | API wrappers - Create your collection of songs & audio features
#
# ### Instructions
#
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster. The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %%
secrets_file = open(r"C:\Users\luana\secrets.txt","r")
string = secrets_file.read()

secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['secret']))

# %%
# I will slice the dataframe to use as test

df_slice = hot_top_songs[0:20]
df_slice
# Out:
#                             song                      artist  year
# 0                         unholy      sam smith & kim petras  2022
# 1                i'm good (blue)   david guetta & bebe rexha  2022
# 2                      thank god  kane brown & katelyn brown  2022
# 3              wait in the truck       hardy & lainey wilson  2022
# 4                son of a sinner                  jelly roll  2022
# 5                      you proof               morgan wallen  2022
# 6               a thousand years             christina perri  2022
# 7                     everywhere               fleetwood mac  2022
# 8                    unstoppable                         sia  2022
# 9                i ain't worried                 onerepublic  2022
# 10                left and right    charlie puth & jung kook  2022
# 11  she had me at heads carolina               cole swindell  2022
# 12                  fall in love            bailey zimmerman  2022
# 13                 wasted on you               morgan wallen  2022
# 14                       cuff it                     beyoncé  2022
# 15           under the influence                 chris brown  2022
# 16      the kind of love we make                  luke combs  2022
# 17              eagle (feat. kb)      transformation worship  2022
# 18              make it with you                       bread  2022
# 19             life is a highway               rascal flatts  2022

# %%
results = sp.search(q='unholy artist:sam smith', type='track', limit=1)
# results

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
# I am gonna use the list that I have and extract spotify information about it
# I will assume that if I search for the song and artist as listed above, the first result will be the correct song

# I will need these queries:

print(results["tracks"]["items"][0]["name"])
print(results["tracks"]["items"][0]["artists"][0]["name"])
print(results["tracks"]["items"][0]["artists"][1]["name"]) # only in case more than one artist: 
# print(results["tracks"]["items"][0]["artists"][2]["name"]) # I will scrape up to 3 in the function
print(results["tracks"]["items"][0]["popularity"])
sp.audio_features(results["tracks"]["items"][0]["id"])
# Out:
# Unholy (feat. Kim Petras)
# Sam Smith
# Kim Petras
# 99
# [{'danceability': 0.714,
#   'energy': 0.472,
#   'key': 2,
#   'loudness': -7.375,
#   'mode': 1,
#   'speechiness': 0.0864,
#   'acousticness': 0.013,
#   'instrumentalness': 4.51e-06,
#   'liveness': 0.266,
#   'valence': 0.238,
#   'tempo': 131.121,
#   'type': 'audio_features',
#   'id': '3nqQXoyQOWXiESFLlDF1hG',
#   'uri': 'spotify:track:3nqQXoyQOWXiESFLlDF1hG',
#   'track_href': 'https://api.spotify.com/v1/tracks/3nqQXoyQOWXiESFLlDF1hG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3nqQXoyQOWXiESFLlDF1hG',
#   'duration_ms': 156943,
#   'time_signature': 4}]

# %%
def get_songs_info(dataframe):
    #creating df with needed columns
    playlist_df = pd.DataFrame(columns=['song','artist','popularity','danceability','energy','key','loudness','mode',
                                    'speechiness','acousticness','instrumentalness','liveness','valence','tempo',
                                    'type','id','uri','track_href','analysis_url','duration_ms','time_signature'])
    
    #for loop to go through a dataframe containing names of songs and artists
    for i in range(len(dataframe)):
        try:
            # Get song's name and artist from the dataframe and generate a query with them
            # Searching with more than one artist wont generate any result, so I will take only the two first words
            # Some songs have too long names and cause a 400(Bad request).Therefore, limiting to 50 characters
            artist_name=dataframe['artist'][i].split(' ')[0]+" "+dataframe['artist'][i].split(' ')[1]
            query = dataframe['song'][i][:50]+" artist:"+artist_name[:50]
            results = sp.search(q=query, type='track', limit=1)
            
            # Song name, artists and popularity obtained directly with request

            song = results["tracks"]["items"][0]["name"]

            # Getting up to three different artists for each song
            artist_1 = results["tracks"]["items"][0]["artists"][0]["name"]
            artist_2 = ''
            try:
                artist_2 = (results["tracks"]["items"][0]["artists"][1]["name"])
                artist_2= " & "+artist_2
            except:
                pass
            artist_3 = ''
            try:
                artist_3 = results["tracks"]["items"][0]["artists"][2]["name"]
                artist_3= " & "+artist_3
            except:
                pass
            artists = (artist_1+artist_2+artist_3)

            popularity = results["tracks"]["items"][0]["popularity"]

            track_dict = {'song':song, 'artist':artists, 'popularity':popularity}
            df_track = pd.DataFrame([track_dict])
            
            # Now the audio features
            song_id = results["tracks"]["items"][0]["id"]
            features_dict = sp.audio_features(song_id)
            df_features = pd.DataFrame(features_dict)
            
            # Complete df for one song
            song_df = pd.concat([df_track, df_features], axis=1)
            
            # Progress report every 25%
            if i == round((len(dataframe)*0.25)):
                print("25% complete")
            elif i == round((len(dataframe)*0.5)):
                print("50% complete")
            elif i == round((len(dataframe)*0.75)):
                print('75% complete')
            else:
                pass
            
            # Respectul nap
            wait_time = random.uniform(0.5,1.5)
            sleep(wait_time)
    
        except:
            pass
        
        try:
            # Complete df with all songs
            playlist_df = pd.concat([playlist_df, song_df],axis=0)
        except:
            pass
    
    return playlist_df

# %%
def get_songs_time(dataframe):
    st = time.time()
    playlist = get_songs_info(dataframe).reset_index(drop=True)
    et = time.time()
    elapsed_time = et - st
    print('Execution time:', elapsed_time/60, 'minutes')

    return playlist

# %%
playlist_slice = get_songs_time(df_slice)
# Out:
# 25% complete
# 50% complete
# 75% complete
# Execution time: 0.2827466487884521 minutes

# %%
playlist_slice
# Out:
#                                        song                          artist  \
# 0                 Unholy (feat. Kim Petras)          Sam Smith & Kim Petras
# 1                           I'm Good (Blue)       David Guetta & Bebe Rexha
# 2                                 Thank God      Kane Brown & Katelyn Brown
# 3                                 Thank God      Kane Brown & Katelyn Brown
# 4                           Son Of A Sinner                      Jelly Roll
# 5                                 You Proof                   Morgan Wallen
# 6                          A Thousand Years                 Christina Perri
# 7                Everywhere - 2017 Remaster                   Fleetwood Mac
# 8                Everywhere - 2017 Remaster                   Fleetwood Mac
# 9                Everywhere - 2017 Remaster                   Fleetwood Mac
# 10  Left and Right (Feat. Jung Kook of BTS)  Charlie Puth & Jung Kook & BTS
# 11             She Had Me At Heads Carolina                   Cole Swindell
# 12                             Fall In Love                Bailey Zimmerman
# 13                            Wasted On You                   Morgan Wallen
# 14                            Wasted On You                   Morgan Wallen
# 15                      Under The Influence                     Chris Brown
# 16                 The Kind of Love We Make                      Luke Combs
# 17                 The Kind of Love We Make                      Luke Combs
# 18                 The Kind of Love We Make                      Luke Combs
# 19                        Life is a Highway                   Rascal Flatts
#
#    popularity danceability energy key loudness mode speechiness acousticness  \
# 0          99        0.714  0.472   2   -7.375    1      0.0864        0.013
# 1          98        0.561  0.965   7   -3.673    0      0.0343      0.00383
# 2          78        0.738  0.455   3   -8.735    1      0.0352        0.695
# 3          78        0.738  0.455   3   -8.735    1      0.0352        0.695
# 4          77        0.365  0.541   7   -7.489    1      0.0304       0.0419
# 5          86        0.731   0.85   9   -4.913    1      0.0336        0.252
# 6          81        0.421  0.407  10   -7.445    1      0.0267        0.309
# 7          78         0.73  0.487   4  -10.991    1      0.0303        0.258
# 8          78         0.73  0.487   4  -10.991    1      0.0303        0.258
# 9          78         0.73  0.487   4  -10.991    1      0.0303        0.258
# 10         93        0.881  0.592   2   -4.898    1      0.0324        0.619
# 11         83        0.607  0.912   8   -3.449    1      0.0611        0.124
# 12         79        0.524  0.643   9   -6.055    1      0.0297        0.451
# 13         83        0.505  0.657  11    -5.24    0      0.0318        0.373
# 14         83        0.505  0.657  11    -5.24    0      0.0318        0.373
# 15         96        0.733   0.69   9   -5.529    0      0.0427       0.0635
# 16         82        0.608  0.745   1    -4.13    1      0.0277       0.0226
# 17         82        0.608  0.745   1    -4.13    1      0.0277       0.0226
# 18         82        0.608  0.745   1    -4.13    1      0.0277       0.0226
# 19         76        0.582  0.952   5   -3.848    1      0.0731      0.00324
#
#     ... liveness valence    tempo            type                      id  \
# 0   ...    0.266   0.238  131.121  audio_features  3nqQXoyQOWXiESFLlDF1hG
# 1   ...    0.371   0.304   128.04  audio_features  4uUG5RXrOk84mYEfFvj3cK
# 2   ...    0.107   0.441   99.945  audio_features  1brnLTvarI9D1hLP6z2Ar8
# 3   ...    0.107   0.441   99.945  audio_features  1brnLTvarI9D1hLP6z2Ar8
# 4   ...    0.281   0.329   86.041  audio_features  25VQoiuyc0HkC5FQTj1a8G
# 5   ...    0.605   0.644  119.706  audio_features  5uU1uuyaUIBOiiUSQG7Wl3
# 6   ...     0.11   0.161  139.028  audio_features  6lanRgr6wXibZr8KgzXxBl
# 7   ...   0.0852   0.731  114.965  audio_features  254bXAqt3zP6P50BdQvEsq
# 8   ...   0.0852   0.731  114.965  audio_features  254bXAqt3zP6P50BdQvEsq
# 9   ...   0.0852   0.731  114.965  audio_features  254bXAqt3zP6P50BdQvEsq
# 10  ...   0.0901   0.719  101.058  audio_features  0mBP9X2gPCuapvpZ7TGDk3
# 11  ...    0.332   0.722  134.944  audio_features  200x8ONbPfFzByUr3fVz46
# 12  ...    0.221   0.397  135.962  audio_features  5gVCfYmQRPy1QJifP8f5gg
# 13  ...    0.126   0.252    196.0  audio_features  3cBsEDNhFI9E82vPj3kvi3
# 14  ...    0.126   0.252    196.0  audio_features  3cBsEDNhFI9E82vPj3kvi3
# 15  ...    0.105    0.31  116.992  audio_features  5IgjP7X4th6nMNDh4akUHb
# 16  ...   0.0942   0.464  102.025  audio_features  28n8z9IQKyjMPxmvYMBqZa
# 17  ...   0.0942   0.464  102.025  audio_features  28n8z9IQKyjMPxmvYMBqZa
# 18  ...   0.0942   0.464  102.025  audio_features  28n8z9IQKyjMPxmvYMBqZa
# 19  ...    0.223   0.655  103.027  audio_features  2Fs18NaCDuluPG1DHGw1XG
#
#                                      uri  \
# 0   spotify:track:3nqQXoyQOWXiESFLlDF1hG
# 1   spotify:track:4uUG5RXrOk84mYEfFvj3cK
# 2   spotify:track:1brnLTvarI9D1hLP6z2Ar8
# 3   spotify:track:1brnLTvarI9D1hLP6z2Ar8
# 4   spotify:track:25VQoiuyc0HkC5FQTj1a8G
# 5   spotify:track:5uU1uuyaUIBOiiUSQG7Wl3
# 6   spotify:track:6lanRgr6wXibZr8KgzXxBl
# 7   spotify:track:254bXAqt3zP6P50BdQvEsq
# 8   spotify:track:254bXAqt3zP6P50BdQvEsq
# 9   spotify:track:254bXAqt3zP6P50BdQvEsq
# 10  spotify:track:0mBP9X2gPCuapvpZ7TGDk3
# 11  spotify:track:200x8ONbPfFzByUr3fVz46
# 12  spotify:track:5gVCfYmQRPy1QJifP8f5gg
# 13  spotify:track:3cBsEDNhFI9E82vPj3kvi3
# 14  spotify:track:3cBsEDNhFI9E82vPj3kvi3
# 15  spotify:track:5IgjP7X4th6nMNDh4akUHb
# 16  spotify:track:28n8z9IQKyjMPxmvYMBqZa
# 17  spotify:track:28n8z9IQKyjMPxmvYMBqZa
# 18  spotify:track:28n8z9IQKyjMPxmvYMBqZa
# 19  spotify:track:2Fs18NaCDuluPG1DHGw1XG
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/3nqQXoyQOWXi...
# 1   https://api.spotify.com/v1/tracks/4uUG5RXrOk84...
# 2   https://api.spotify.com/v1/tracks/1brnLTvarI9D...
# 3   https://api.spotify.com/v1/tracks/1brnLTvarI9D...
# 4   https://api.spotify.com/v1/tracks/25VQoiuyc0Hk...
# 5   https://api.spotify.com/v1/tracks/5uU1uuyaUIBO...
# 6   https://api.spotify.com/v1/tracks/6lanRgr6wXib...
# 7   https://api.spotify.com/v1/tracks/254bXAqt3zP6...
# 8   https://api.spotify.com/v1/tracks/254bXAqt3zP6...
# 9   https://api.spotify.com/v1/tracks/254bXAqt3zP6...
# 10  https://api.spotify.com/v1/tracks/0mBP9X2gPCua...
# 11  https://api.spotify.com/v1/tracks/200x8ONbPfFz...
# 12  https://api.spotify.com/v1/tracks/5gVCfYmQRPy1...
# 13  https://api.spotify.com/v1/tracks/3cBsEDNhFI9E...
# 14  https://api.spotify.com/v1/tracks/3cBsEDNhFI9E...
# 15  https://api.spotify.com/v1/tracks/5IgjP7X4th6n...
# 16  https://api.spotify.com/v1/tracks/28n8z9IQKyjM...
# 17  https://api.spotify.com/v1/tracks/28n8z9IQKyjM...
# 18  https://api.spotify.com/v1/tracks/28n8z9IQKyjM...
# 19  https://api.spotify.com/v1/tracks/2Fs18NaCDulu...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/3nqQ...      156943
# 1   https://api.spotify.com/v1/audio-analysis/4uUG...      175238
# 2   https://api.spotify.com/v1/audio-analysis/1brn...      174560
# 3   https://api.spotify.com/v1/audio-analysis/1brn...      174560
# 4   https://api.spotify.com/v1/audio-analysis/25VQ...      232093
# 5   https://api.spotify.com/v1/audio-analysis/5uU1...      157478
# 6   https://api.spotify.com/v1/audio-analysis/6lan...      285120
# 7   https://api.spotify.com/v1/audio-analysis/254b...      226653
# 8   https://api.spotify.com/v1/audio-analysis/254b...      226653
# 9   https://api.spotify.com/v1/audio-analysis/254b...      226653
# 10  https://api.spotify.com/v1/audio-analysis/0mBP...      154487
# 11  https://api.spotify.com/v1/audio-analysis/200x...      206107
# 12  https://api.spotify.com/v1/audio-analysis/5gVC...      232059
# 13  https://api.spotify.com/v1/audio-analysis/3cBs...      178520
# 14  https://api.spotify.com/v1/audio-analysis/3cBs...      178520
# 15  https://api.spotify.com/v1/audio-analysis/5Igj...      184613
# 16  https://api.spotify.com/v1/audio-analysis/28n8...      224427
# 17  https://api.spotify.com/v1/audio-analysis/28n8...      224427
# 18  https://api.spotify.com/v1/audio-analysis/28n8...      224427
# 19  https://api.spotify.com/v1/audio-analysis/2Fs1...      276320
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               3
# 7               4
# 8               4
# 9               4
# 10              4
# 11              4
# 12              4
# 13              3
# 14              3
# 15              4
# 16              4
# 17              4
# 18              4
# 19              4
#
# [20 rows x 21 columns]

# %%
# Let´s be bold and see what happens :D

# playlist_df = get_songs_time(hot_top_songs) #as comment to not risk running it again by accident
# Out:
# 25% complete
# 50% complete
# 75% complete
# Execution time: 75.90357853968938 minutes

# %%
# Maybe I can reduce the sleeping time, but I do not want to risk being banned by Spotify

# %%
playlist_df.shape
# Out:
# (5197, 22)

# %%
playlist_df
# Out:
#                                song                      artist popularity  \
# 0         Unholy (feat. Kim Petras)      Sam Smith & Kim Petras         99
# 1                   I'm Good (Blue)   David Guetta & Bebe Rexha         98
# 2                         Thank God  Kane Brown & Katelyn Brown         78
# 3                         Thank God  Kane Brown & Katelyn Brown         78
# 4                   Son Of A Sinner                  Jelly Roll         77
# ...                             ...                         ...        ...
# 5192   He's Gonna Step on You Again                 John Kongos         28
# 5193                     Wild World         Yusuf / Cat Stevens         77
# 5194                 Love Her Madly                   The Doors         66
# 5195                  Amazing Grace                Judy Collins         45
# 5196  Peace Train - Remastered 2021         Yusuf / Cat Stevens         66
#
#      danceability energy key loudness mode speechiness acousticness  ...  \
# 0           0.714  0.472   2   -7.375    1      0.0864        0.013  ...
# 1           0.561  0.965   7   -3.673    0      0.0343      0.00383  ...
# 2           0.738  0.455   3   -8.735    1      0.0352        0.695  ...
# 3           0.738  0.455   3   -8.735    1      0.0352        0.695  ...
# 4           0.365  0.541   7   -7.489    1      0.0304       0.0419  ...
# ...           ...    ...  ..      ...  ...         ...          ...  ...
# 5192        0.712  0.874   0   -6.835    0      0.0328       0.0167  ...
# 5193         0.48  0.542   0    -8.51    1      0.0348        0.345  ...
# 5194        0.565  0.587   4   -7.393    0      0.0317       0.0573  ...
# 5195        0.192  0.263   3   -11.83    1      0.0332        0.945  ...
# 5196        0.594  0.682   0   -8.858    1      0.0487        0.051  ...
#
#      valence    tempo            type                      id  \
# 0      0.238  131.121  audio_features  3nqQXoyQOWXiESFLlDF1hG
# 1      0.304   128.04  audio_features  4uUG5RXrOk84mYEfFvj3cK
# 2      0.441   99.945  audio_features  1brnLTvarI9D1hLP6z2Ar8
# 3      0.441   99.945  audio_features  1brnLTvarI9D1hLP6z2Ar8
# 4      0.329   86.041  audio_features  25VQoiuyc0HkC5FQTj1a8G
# ...      ...      ...             ...                     ...
# 5192   0.705  107.083  audio_features  4Kqp11O4KoQ6cHAtH9Kf1x
# 5193   0.567  152.853  audio_features  7mjSHL2Eb0kAwiKbvNNyD9
# 5194   0.966  147.462  audio_features  3MFFDRC4wTN9JNGtzXsZlN
# 5195   0.196   87.747  audio_features  6Sueudn0VQA4AXRsFKQbFl
# 5196    0.76   82.487  audio_features  4d0d2llNcQIHmaCgYTrODQ
#
#                                        uri  \
# 0     spotify:track:3nqQXoyQOWXiESFLlDF1hG
# 1     spotify:track:4uUG5RXrOk84mYEfFvj3cK
# 2     spotify:track:1brnLTvarI9D1hLP6z2Ar8
# 3     spotify:track:1brnLTvarI9D1hLP6z2Ar8
# 4     spotify:track:25VQoiuyc0HkC5FQTj1a8G
# ...                                    ...
# 5192  spotify:track:4Kqp11O4KoQ6cHAtH9Kf1x
# 5193  spotify:track:7mjSHL2Eb0kAwiKbvNNyD9
# 5194  spotify:track:3MFFDRC4wTN9JNGtzXsZlN
# 5195  spotify:track:6Sueudn0VQA4AXRsFKQbFl
# 5196  spotify:track:4d0d2llNcQIHmaCgYTrODQ
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3nqQXoyQOWXi...
# 1     https://api.spotify.com/v1/tracks/4uUG5RXrOk84...
# 2     https://api.spotify.com/v1/tracks/1brnLTvarI9D...
# 3     https://api.spotify.com/v1/tracks/1brnLTvarI9D...
# 4     https://api.spotify.com/v1/tracks/25VQoiuyc0Hk...
# ...                                                 ...
# 5192  https://api.spotify.com/v1/tracks/4Kqp11O4KoQ6...
# 5193  https://api.spotify.com/v1/tracks/7mjSHL2Eb0kA...
# 5194  https://api.spotify.com/v1/tracks/3MFFDRC4wTN9...
# 5195  https://api.spotify.com/v1/tracks/6Sueudn0VQA4...
# 5196  https://api.spotify.com/v1/tracks/4d0d2llNcQIH...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3nqQ...      156943
# 1     https://api.spotify.com/v1/audio-analysis/4uUG...      175238
# 2     https://api.spotify.com/v1/audio-analysis/1brn...      174560
# 3     https://api.spotify.com/v1/audio-analysis/1brn...      174560
# 4     https://api.spotify.com/v1/audio-analysis/25VQ...      232093
# ...                                                 ...         ...
# 5192  https://api.spotify.com/v1/audio-analysis/4Kqp...      260773
# 5193  https://api.spotify.com/v1/audio-analysis/7mjS...      200560
# 5194  https://api.spotify.com/v1/audio-analysis/3MFF...      198467
# 5195  https://api.spotify.com/v1/audio-analysis/6Sue...      248693
# 5196  https://api.spotify.com/v1/audio-analysis/4d0d...      253293
#
#      time_signature    0
# 0                 4  NaN
# 1                 4  NaN
# 2                 4  NaN
# 3                 4  NaN
# 4                 4  NaN
# ...             ...  ...
# 5192              5  NaN
# 5193              4  NaN
# 5194              4  NaN
# 5195              4  NaN
# 5196              4  NaN
#
# [5197 rows x 22 columns]

# %%
#exporting csv so that I dont have to run it again every time I restart the notebook
playlist_df.to_csv(r'C:\Users\luana\IH-Labs\lab-web-scraping-multiple-pages\playlist_df.csv', index = False, header=True)
